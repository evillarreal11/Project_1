# %%
import pandas as pd
from pathlib import Path
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt

# %%
sleep_data=Path("archive/Sleep_health_and_lifestyle_dataset.csv")
sleep_data_df=pd.read_csv(sleep_data)
sleep_data_df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
disorder_df=sleep_data_df[["Gender", "Age", "Sleep Disorder", "Sleep Duration"]]
disorder_df
# Out:
#      Gender  Age Sleep Disorder  Sleep Duration
# 0      Male   27           None             6.1
# 1      Male   28           None             6.2
# 2      Male   28           None             6.2
# 3      Male   28    Sleep Apnea             5.9
# 4      Male   28    Sleep Apnea             5.9
# ..      ...  ...            ...             ...
# 369  Female   59    Sleep Apnea             8.1
# 370  Female   59    Sleep Apnea             8.0
# 371  Female   59    Sleep Apnea             8.1
# 372  Female   59    Sleep Apnea             8.1
# 373  Female   59    Sleep Apnea             8.1
#
# [374 rows x 4 columns]

# %%
dub_disorder_df=disorder_df.loc[sleep_df["Gender", "Sleep Duration"]=="Female"]
dub_disorder_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dub_disorder_df=disorder_df.loc[sleep_df["Gender"]=="Female"]
#       2 dub_disorder_df
#
# NameError: name 'sleep_df' is not defined
